# %%
# doom project
# first i will start to import the modules for the project most importent vizdoom 
from vizdoom import * # and the vizdoom for the dom game envirnoment 
import random # her this for action sampling 
import time
import numpy as np

# %%
# setup the game 
game = DoomGame()
game.load_config(r"C:\Users\HP\Desktop\doom_in\ViZDoom\scenarios\defend_the_center.cfg")# load the game sittings 
game.init()

# %%
actions = np.identity(3, dtype = np.uint) # the identity matrix of 3x3 matrix 
# so we made this identity matrix as in this game there is 3 avalibale botton (things the agent can do ) move left , move right , attack 
# so each one fo them will have its own array from the identity matrix [1,0,0] --> to move left etc....

# %%
# her we lopped throght the episodes 
episodes = 10 
for episode in range(episodes):
    game.new_episode() # her each loop we make new game 
    while not game.is_episode_finished():
        state = game.get_state()
        img = state.screen_buffer
        info = state.game_variables
        reward = game.make_action(random.choice(actions),4)
        print("the reward", reward)
        time.sleep(0.02)
    print("result:", game.get_total_reward())
    time.sleep(2)
# Out:
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: -1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: -1.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: -1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward -1.0
# result: 1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 1.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward 0.0
# the reward -1.0
# result: -1.0

# %%
game.close()

# %%
# so for better use for machine learning we will convert it to gym envirnoment 
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete , Box
import cv2 # open cv , we can use it to gray scale our observation

# %%
# start by creating vizdoom openai gym(i used gymnasium as it is the updates version of gym both nearly the same) envirnoment 
class vizdoomgym(Env):
    def __init__(self, render = False):
        super().__init__() # inheret from ore base Env class 
        # setup the game 
        self.game = DoomGame()
        self.game.load_config(r"C:\Users\HP\Desktop\doom_in\ViZDoom\scenarios\defend_the_center.cfg")
        
        # see if we want ro render the game or only let it process with out watching it 
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # her i Create the action space and observation space for the game 
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
    def step(self, action):
        actions = np.identity(3, dtype = np.uint)
        reward = self.game.make_action(actions[action],4)
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]  
            info = dict({"ammo": ammo})      
        else:
            state = np.zeros(self.observation_space.shape)
            info = dict({"ammo": 0})

        done = self.game.is_episode_finished()
        
        return state, reward,done,False, info 
    def close(self):
        self.game.close()
    def render():
        pass
    def grayscale(self,observation):
        gray = cv2.cvtColor(np.moveaxis(observation,0,-1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation = cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    def reset(self,seed=None):
        if seed is not None:
            np.random.seed(seed)
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        
        return self.grayscale(state), {}

# %%
env = vizdoomgym(render = True)

# %%
state = env.reset()

# %%
env.close()

# %%
# envirnoment chacker 
from stable_baselines3.common import env_checker # cheack if the envirnoment i made is valid or not

# %%
env_checker.check_env(env) # we got valid envirnoment

# %%
# view the game 
import matplotlib.pyplot as plt
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
# now we will start to setup the calback 
# as if some thing happend while train we will have the best version of the model # and can even adjust with it more options

# %%
import os 
from stable_baselines3.common.callbacks import BaseCallback # import callbacks from stable-baseline the library we will used for the model and 
# reinforcment learning things

# %%
class callback(BaseCallback):
    def __init__(self,check_frq, save_path, verbose =1):
        super(callback, self).__init__(verbose)
        self.check_frq = check_frq
        self.save_path = save_path
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_frq == 0: # ensure to save the model every 10000 step 
            model_path = os.path.join(self.save_path, "best_model{}".format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
check_dir = "./train/train_defend"
log_dir = "./logs/log_defend"

# %%
cb = callback(check_frq=10000 , save_path =check_dir) # calback instance

# %%
# train our model 
# we will use the PPO algorithm from stable-baseline 
from stable_baselines3 import PPO

# %%
env = vizdoomgym() # take an instance from our envirnoment that will not be rendered while training

# %%
model = PPO('CnnPolicy', env , tensorboard_log=log_dir, verbose =1, learning_rate=0.0001, n_steps=4096,device='cuda')
# the n_step number is simply how many frames(steps) the agent going to take and store in the buffer before it go and run yhe actor and critic

# %%
model.learn(total_timesteps=100000, callback=cb)
# it will give us like 2 matrices 
# first one the thimgs in it represent the information collected during envirnoment interaction 
# the second one represet some statistics from the training process
# Out:
# Logging to ./logs/log_defend\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.2     |
# |    ep_rew_mean     | 0.28     |
# | time/              |          |
# |    fps             | 19       |
# |    iterations      | 1        |
# |    time_elapsed    | 214      |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 0.537       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 2           |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008079686 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0201329  |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0731      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.6        |
# |    ep_rew_mean          | 1.37        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 3           |
# |    time_elapsed         | 1036        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010874081 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.44529176  |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0202      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 2.22        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 4           |
# |    time_elapsed         | 1449        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013594817 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.4886648   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00353    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 0.135       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 2.91        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 5           |
# |    time_elapsed         | 1855        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013154017 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.58426     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0247      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0319     |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 112        |
# |    ep_rew_mean          | 3.36       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 6          |
# |    time_elapsed         | 2261       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01819184 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.909     |
# |    explained_variance   | 0.5617982  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0091    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0341    |
# |    value_loss           | 0.183      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | 3.92        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 7           |
# |    time_elapsed         | 2671        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015566511 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.5993159   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0152     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 0.178       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 124       |
# |    ep_rew_mean          | 4.51      |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 8         |
# |    time_elapsed         | 3074      |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0173672 |
# |    clip_fraction        | 0.189     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.87     |
# |    explained_variance   | 0.7046182 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 0.00969   |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.0387   |
# |    value_loss           | 0.155     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 133        |
# |    ep_rew_mean          | 5.28       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 9          |
# |    time_elapsed         | 3702       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02206652 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.837     |
# |    explained_variance   | 0.73232234 |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0463    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0411    |
# |    value_loss           | 0.167      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 5.76        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 10          |
# |    time_elapsed         | 4114        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022023888 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.7558432   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.052      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 6.22        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 11          |
# |    time_elapsed         | 4523        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021190073 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.74016905  |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0162     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 0.202       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 6.8         |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 12          |
# |    time_elapsed         | 4929        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023547344 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.7909194   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0465     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0442     |
# |    value_loss           | 0.187       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 7.01        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 13          |
# |    time_elapsed         | 5681        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.028836071 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0.7868273   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0314     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 0.175       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 7.38        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 14          |
# |    time_elapsed         | 6092        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.031154621 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.86057234  |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0226     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 7.83        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 15          |
# |    time_elapsed         | 6495        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.027503315 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.8560483   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0205     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.186       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | 8.3         |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 16          |
# |    time_elapsed         | 6907        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.026823966 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.8611312   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00542    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 0.186       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 9.24        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 17          |
# |    time_elapsed         | 7306        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.027834542 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.8738282   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0318     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 9.96        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 18          |
# |    time_elapsed         | 7711        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.027485996 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.90098524  |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0375     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 0.154       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 198        |
# |    ep_rew_mean          | 10.5       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 19         |
# |    time_elapsed         | 8123       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02374531 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.631     |
# |    explained_variance   | 0.9232839  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0562    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.042     |
# |    value_loss           | 0.171      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 20          |
# |    time_elapsed         | 8528        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.028567761 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.92179066  |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0127     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0406     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 21          |
# |    time_elapsed         | 8949        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.030859414 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.93185306  |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0222      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0402     |
# |    value_loss           | 0.16        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 206        |
# |    ep_rew_mean          | 11.5       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 22         |
# |    time_elapsed         | 9356       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.02864704 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.557     |
# |    explained_variance   | 0.92345595 |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0363    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0382    |
# |    value_loss           | 0.161      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 211        |
# |    ep_rew_mean          | 11.8       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 23         |
# |    time_elapsed         | 9767       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03290015 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.548     |
# |    explained_variance   | 0.9284713  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00523   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0386    |
# |    value_loss           | 0.155      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 24          |
# |    time_elapsed         | 10187       |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.028134707 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.9334712   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0322      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 222        |
# |    ep_rew_mean          | 12.7       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 25         |
# |    time_elapsed         | 10608      |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.03401141 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.514     |
# |    explained_variance   | 0.9420855  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0112     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0393    |
# |    value_loss           | 0.15       |
# ----------------------------------------

# %%
# test and check the model 
# in stable - baseline we have evaluatiing_policy that can evaluate our model 

from stable_baselines3.common.evaluation import evaluate_policy

# %%
model_100 = PPO.load(r"C:\Users\HP\Desktop\0e135d5a-5fda-4499-997b-1bfd5abaaa1b_FlaskChess.zip.a1b\train\train_defend\best_model100000.zip")

# %%
env = vizdoomgym(render = True)

# %%
mean_reward ,_ = evaluate_policy(model_100 , env , n_eval_episodes=2)

# %%
mean_reward
# Out:
# np.float64(18.5)

# %%
env.close()
